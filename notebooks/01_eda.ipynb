# %% [markdown]
# # 01 - Análisis Exploratorio de Datos (EDA)
#
# Notebook de exploración inicial del dataset logístico de SmartDelay AI 360.
#
# **Objetivos:**
# - Entender la calidad y distribución de los datos
# - Identificar nulos, outliers y patrones temporales
# - Calcular KPIs iniciales: tasa de retraso, ingresos, costos
# - Generar insights para feature engineering

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.utils import cargar_dataset, configurar_logger

configurar_logger('eda')
sns.set_theme(style='whitegrid')

# %% [markdown]
# ## 1. Carga del dataset crudo

# %%
# df = cargar_dataset('guias.csv', capa='raw')
# df.head()

# %% [markdown]
# ## 2. Calidad de datos

# %%
# df.info()
# df.isna().sum().sort_values(ascending=False)

# %% [markdown]
# ## 3. Distribuciones

# %%
# df.describe()

# %% [markdown]
# ## 4. KPIs iniciales
# - Tasa de retraso
# - Top rutas por volumen
# - Distribución de valor de flete
